# %%
import pandas as pd
import seaborn as sns

# %%
data=pd.read_csv("2015_Street_Tree_Census_-_Tree_Data.csv")
data
# Out:
#         tree_id  block_id  created_at  tree_dbh  stump_diam curb_loc status  \
# 0        180683    348711  08/27/2015         3           0   OnCurb  Alive
# 1        200540    315986  09/03/2015        21           0   OnCurb  Alive
# 2        204026    218365  09/05/2015         3           0   OnCurb  Alive
# 3        204337    217969  09/05/2015        10           0   OnCurb  Alive
# 4        189565    223043  08/30/2015        21           0   OnCurb  Alive
# ...         ...       ...         ...       ...         ...      ...    ...
# 683783   155433    217978  08/18/2015        25           0   OnCurb  Alive
# 683784   183795    348185  08/29/2015         7           0   OnCurb  Alive
# 683785   166161    401670  08/22/2015        12           0   OnCurb  Alive
# 683786   184028    504204  08/29/2015         9           0   OnCurb  Alive
# 683787   200607    306527  09/03/2015        23           0   OnCurb  Alive
#
# ...

# %%
data.shape
# Out:
# (683788, 45)

# %%
data.columns
# Out:
# Index(['tree_id', 'block_id', 'created_at', 'tree_dbh', 'stump_diam',
#        'curb_loc', 'status', 'health', 'spc_latin', 'spc_common', 'steward',
#        'guards', 'sidewalk', 'user_type', 'problems', 'root_stone',
#        'root_grate', 'root_other', 'trunk_wire', 'trnk_light', 'trnk_other',
#        'brch_light', 'brch_shoe', 'brch_other', 'address', 'postcode',
#        'zip_city', 'community board', 'borocode', 'borough', 'cncldist',
#        'st_assem', 'st_senate', 'nta', 'nta_name', 'boro_ct', 'state',
#        'latitude', 'longitude', 'x_sp', 'y_sp', 'council district',
#        'census tract', 'bin', 'bbl'],
#       dtype='object')

# %%
#data.drop["Name', 'Sex', 'Age','Parch', 'Fare', 'Cabin', 'Embarked']

# %%
data.dtypes
# Out:
# tree_id               int64
# block_id              int64
# created_at           object
# tree_dbh              int64
# stump_diam            int64
# curb_loc             object
# status               object
# health               object
# spc_latin            object
# spc_common           object
# steward              object
# guards               object
# sidewalk             object
# user_type            object
# problems             object
# root_stone           object
# root_grate           object
# root_other           object
# trunk_wire           object
# trnk_light           object
# trnk_other           object
# brch_light           object
# brch_shoe            object
# brch_other           object
# address              object
# postcode              int64
# zip_city             object
# community board       int64
# borocode              int64
# borough              object
# cncldist              int64
# st_assem              int64
# st_senate             int64
# ...

# %%
data.isnull().sum()
# Out:
# tree_id                 0
# block_id                0
# created_at              0
# tree_dbh                0
# stump_diam              0
# curb_loc                0
# status                  0
# health              31616
# spc_latin           31619
# spc_common          31619
# steward             31615
# guards              31616
# sidewalk            31616
# user_type               0
# problems            31664
# root_stone              0
# root_grate              0
# root_other              0
# trunk_wire              0
# trnk_light              0
# trnk_other              0
# brch_light              0
# brch_shoe               0
# brch_other              0
# address                 0
# postcode                0
# zip_city                0
# community board         0
# borocode                0
# borough                 0
# cncldist                0
# st_assem                0
# st_senate               0
# nta                     0
# nta_name                0
# ...

# %%
data.describe()
# Out:
#              tree_id       block_id       tree_dbh     stump_diam  \
# count  683788.000000  683788.000000  683788.000000  683788.000000
# mean   365205.011085  313793.096236      11.279787       0.432463
# std    208122.092902  114839.024312       8.723042       3.290241
# min         3.000000  100002.000000       0.000000       0.000000
# 25%    186582.750000  221556.000000       4.000000       0.000000
# 50%    366214.500000  319967.000000       9.000000       0.000000
# 75%    546170.250000  404624.000000      16.000000       0.000000
# max    722694.000000  999999.000000     450.000000     140.000000
#
#             postcode  community board       borocode       cncldist  \
# count  683788.000000    683788.000000  683788.000000  683788.000000
# mean    10916.246044       343.505404       3.358500      29.943181
# std       651.553364       115.740601       1.166746      14.328531
# min        83.000000       101.000000       1.000000       1.000000
# ...

# %%
[features for features in data.columns if data[features].isnull().sum()>0]
# Out:
# ['health',
#  'spc_latin',
#  'spc_common',
#  'steward',
#  'guards',
#  'sidewalk',
#  'problems',
#  'council district',
#  'census tract',
#  'bin',
#  'bbl']

# %%
[features for features in data.columns if data[features].isnull().sum()>10000]
# Out:
# ['health',
#  'spc_latin',
#  'spc_common',
#  'steward',
#  'guards',
#  'sidewalk',
#  'problems']

# %%
[features for features in data.columns if data[features].isnull().sum()<10000]
# Out:
# ['tree_id',
#  'block_id',
#  'created_at',
#  'tree_dbh',
#  'stump_diam',
#  'curb_loc',
#  'status',
#  'user_type',
#  'root_stone',
#  'root_grate',
#  'root_other',
#  'trunk_wire',
#  'trnk_light',
#  'trnk_other',
#  'brch_light',
#  'brch_shoe',
#  'brch_other',
#  'address',
#  'postcode',
#  'zip_city',
#  'community board',
#  'borocode',
#  'borough',
#  'cncldist',
#  'st_assem',
#  'st_senate',
#  'nta',
#  'nta_name',
#  'boro_ct',
#  'state',
#  'latitude',
#  'longitude',
#  'x_sp',
#  'y_sp',
#  'council district',
#  'census tract',
#  'bin',
#  'bbl']

# %%
sns.heatmap(data.isnull(),yticklabels=False,cbar=False,cmap="viridis")
# Out:
# <AxesSubplot:>

# %%
trees=data[['tree_id', 'tree_dbh', 'stump_diam',
       'curb_loc', 'status', 'health', 'spc_latin','steward', 'sidewalk', 'problems', 'root_stone',
       'root_grate', 'root_other', 'trunk_wire', 'trnk_light', 'trnk_other',
       'brch_light', 'brch_shoe', 'brch_other',]]
trees
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health  \
# 0        180683         3           0   OnCurb  Alive   Fair
# 1        200540        21           0   OnCurb  Alive   Fair
# 2        204026         3           0   OnCurb  Alive   Good
# 3        204337        10           0   OnCurb  Alive   Good
# 4        189565        21           0   OnCurb  Alive   Good
# ...         ...       ...         ...      ...    ...    ...
# 683783   155433        25           0   OnCurb  Alive   Good
# 683784   183795         7           0   OnCurb  Alive   Good
# 683785   166161        12           0   OnCurb  Alive   Good
# 683786   184028         9           0   OnCurb  Alive   Good
# 683787   200607        23           0   OnCurb  Alive   Fair
#
#                                  spc_latin steward  sidewalk problems  \
# 0                              Acer rubrum    None  NoDamage     None
# 1                        Quercus palustris    None    Damage   Stones
# ...

# %%
trees.shape
# Out:
# (683788, 19)

# %%
trees.corr()
# Out:
#              tree_id  tree_dbh  stump_diam
# tree_id     1.000000  0.098413    0.012563
# tree_dbh    0.098413  1.000000   -0.169963
# stump_diam  0.012563 -0.169963    1.000000

# %%
sns.heatmap(trees.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
trees[trees["health"].isna()]
# Out:
#         tree_id  tree_dbh  stump_diam        curb_loc status health spc_latin  \
# 37       211205         0          16          OnCurb  Stump    NaN       NaN
# 57       187807         0           0          OnCurb   Dead    NaN       NaN
# 196      208322        10           0          OnCurb   Dead    NaN       NaN
# 209      209058         6           0          OnCurb   Dead    NaN       NaN
# 239      203597         0          15          OnCurb  Stump    NaN       NaN
# ...         ...       ...         ...             ...    ...    ...       ...
# 683693   156162         3           0  OffsetFromCurb   Dead    NaN       NaN
# 683695   170888         0           5          OnCurb  Stump    NaN       NaN
# 683697   177922         0          17          OnCurb  Stump    NaN       NaN
# 683698   193791         3           0          OnCurb   Dead    NaN       NaN
# 683699   172660         0           4          OnCurb  Stump    NaN       NaN
#
# ...

# %%
trees.describe()
# Out:
#              tree_id       tree_dbh     stump_diam
# count  683788.000000  683788.000000  683788.000000
# mean   365205.011085      11.279787       0.432463
# std    208122.092902       8.723042       3.290241
# min         3.000000       0.000000       0.000000
# 25%    186582.750000       4.000000       0.000000
# 50%    366214.500000       9.000000       0.000000
# 75%    546170.250000      16.000000       0.000000
# max    722694.000000     450.000000     140.000000

# %%
trees.dtypes
# Out:
# tree_id        int64
# tree_dbh       int64
# stump_diam     int64
# curb_loc      object
# status        object
# health        object
# spc_latin     object
# steward       object
# sidewalk      object
# problems      object
# root_stone    object
# root_grate    object
# root_other    object
# trunk_wire    object
# trnk_light    object
# trnk_other    object
# brch_light    object
# brch_shoe     object
# brch_other    object
# dtype: object

# %%
trees.hist(bins=60,figsize=(20,10))
# Out:
# array([[<AxesSubplot:title={'center':'tree_id'}>,
#         <AxesSubplot:title={'center':'tree_dbh'}>],
#        [<AxesSubplot:title={'center':'stump_diam'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
bigtrees=trees[trees["tree_dbh"]>50]
bigtrees
# Out:
#         tree_id  tree_dbh  stump_diam        curb_loc status health  \
# 2405     168583       425           0          OnCurb  Alive   Good
# 3738     199546        51           0          OnCurb  Alive   Good
# 4887     139665        72           0  OffsetFromCurb  Alive   Good
# 6724     209349       122           0          OnCurb  Alive   Good
# 10083    215075       169           0          OnCurb  Alive   Good
# ...         ...       ...         ...             ...    ...    ...
# 675265   179496        52           0  OffsetFromCurb  Alive   Good
# 677954   166796        54           0          OnCurb  Alive   Good
# 679894   169501        51           0          OnCurb  Alive   Good
# 681736   179366       281           0          OnCurb  Alive   Fair
# 682788   183910       127           0          OnCurb   Dead    NaN
#
#                                  spc_latin steward  sidewalk      problems  \
# ...

# %%
trees[["tree_id","tree_dbh"]].plot(kind="scatter",x="tree_id",y="tree_dbh",figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='tree_id', ylabel='tree_dbh'>

# %%
#greater diameter trees
trees["spc_latin"].value_counts()
# Out:
# Platanus x acerifolia                 87014
# Gleditsia triacanthos var. inermis    64264
# Pyrus calleryana                      58931
# Quercus palustris                     53185
# Acer platanoides                      34189
#                                       ...
# Pinus nigra                              37
# Pinus rigida                             33
# Maclura pomifera                         29
# Pinus sylvestris                         25
# Pinus virginiana                         10
# Name: spc_latin, Length: 132, dtype: int64

# %%
pd.DataFrame(trees["spc_latin"].value_counts()).plot(kind="bar",figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
Itree=pd.DataFrame(trees["spc_latin"].value_counts()).plot(kind="bar",figsize=(20,10))
Itree.head(5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\SAJANM~1\AppData\Local\Temp/ipykernel_12044/1417043613.py in <module>
#       1 Itree=pd.DataFrame(trees["spc_latin"].value_counts()).plot(kind="bar",figsize=(20,10))
# ----> 2 Itree.head(5)
#
# AttributeError: 'AxesSubplot' object has no attribute 'head'
